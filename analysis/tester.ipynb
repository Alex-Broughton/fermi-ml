# %%
from astropy.io import fits
import numpy as np
import os
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from astropy.wcs import WCS

#the reprojection is done for each map corresponding to number of GALPROP radial bins:
i = 8

this_dir  = "/pub/abrought/GALPROPModels/1sigma/tiled_alt/Masked/"
#this_file = "reprojected_pion_decay_HIR_mapcube_comp_%i_56_Mopra.gz" %i
this_file = "masked_reprojected_pion_decay_HIR_mapcube_comp_0_5_56_Mopra.fits"
file = this_dir + this_file

if os.path.isfile(file):
    print("Retrieving file:")
    hdu = fits.open(file)
    hdu.info()
else:
    print("File not found.")

#fits.setval(this_dir + this_file, 'CUNIT3', value='MeV')
#print("Fixed header.")
# Out:
# Retrieving file:
# Filename: /pub/abrought/GALPROPModels/1sigma/tiled_alt/Masked/masked_reprojected_pion_decay_HIR_mapcube_comp_0_5_56_Mopra.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      25   (1920, 96, 21)   float64
#   1  ENERGIES      1 BinTableHDU     12   21R x 1C   [D]

# %%
fig = plt.figure(figsize=(20,6))
im = plt.imshow(np.sum(hdu[0].data, axis=0)) #, norm=LogNorm()
cax = fig.add_axes([.91, .425, 0.01, 0.15])
plt.colorbar(im, cax=cax)
print("Checksum: ", np.sum(hdu[0].data))
# Out:
# ('Checksum: ', 4.04152931438757e+16)
